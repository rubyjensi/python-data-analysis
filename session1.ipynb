# %% [markdown]
# <a href="https://colab.research.google.com/github/rubyjensi/python-data-analysis/blob/main/session1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### This is my practice notebook for the 'Data Analysis with Python: Zero to Pandas' course by freeCodeCamp and Jovian. [Lesson1]

# %%
my_favorite_number = 1

# %%
my_least_favorute_number = 3

# %%
a_neutral_number = 5

# %%
my_favorite_number = 1
my_least_favorite_number = 5
a_netral_number = 3

# %%
my_favorite_number == 1
# Out:
# True

# %%
my_favorite_number == my_least_favorite_number
# Out:
# False

# %%
my_favorite_number != a_netral_number
# Out:
# True

# %%
a_netral_number != 3
# Out:
# False

# %%
my_favorite_number > my_least_favorite_number
# Out:
# False

# %%
my_favorite_number > my_least_favorite_number
# Out:
# False

# %%
my_favorite_number < 10
# Out:
# True

# %%
my_least_favorite_number < my_favorite_number
# Out:
# False

# %%
my_favorite_number >=1
# Out:
# True

# %%
my_favorite_number >=3
# Out:
# False

# %%
3 + 6 <= 9
# Out:
# True

# %%
my_favorite_number + a_neutral_number <= 3
# Out:
# False

# %%
cost_of_ice_bag = 1.25
is_ice_bag_expensive = cost_of_ice_bag >=10
print("Is the ice bag expensive?", is_ice_bag_expensive)
# Out:
# Is the ice bag expensive? False

# %%
not a_neutral_number == 3
# Out:
# False

# %%
not my_favorite_number < 0
# Out:
# True

# %%
not False
# Out:
# True

# %%
not True
# Out:
# False

# %%
(2 > 3 and 4 <=5) or not (my_favorite_number < 0 and True)
# Out:
# True

# %%
not (True and 0 < 1) or (False and True)
# Out:
# False

# %%
my_favorite_color = "blue"

# %%
my_favorite_color
# Out:
# 'blue'

# %%
color1, color2, color3 = "red", "green", "blue"

# %%
color1
# Out:
# 'red'

# %%
color2
# Out:
# 'green'

# %%
color3
# Out:
# 'blue'

# %%
color4 = color5 = color6 = "magenta"

# %%
color4
# Out:
# 'magenta'

# %%
color5
# Out:
# 'magenta'

# %%
color6
# Out:
# 'magenta'

# %%
my_favorite_color = "red"

# %%
my_favorite_color
# Out:
# 'red'

# %%
counter = 10

# %%
counter = counter + 1

# %%
counter
# Out:
# 11

# %%
counter = 10

# %%
counter += 4

# %%
counter
# Out:
# 14

# %%
a_variable = 23
is_today_Saturday = False

# %%
myfavoritecar = "Delorean"
the3muskeeters = ["Athos", "Porthos", "Aramis"]

# %%
a_variable
# Out:
# 23

# %%
type(a_variable)
# Out:
# int

# %%
type(is_today_Saturday)
# Out:
# bool

# %%
type(myfavoritecar)
# Out:
# str

# %%
type(the3muskeeters)
# Out:
# list

# %%
a_number = 3.0

# %%
a_number
# Out:
# 3.0

# %%
type(a_number)
# Out:
# float

# %%
another_number = 4.

# %%
another_number
# Out:
# 4.0

# %%
type(another_number)
# Out:
# float

# %%
one_hundredth = 1e-2

# %%
one_hundredth
# Out:
# 0.01

# %%
type(one_hundredth)
# Out:
# float

# %%
avogadro_number = 6.02214076e23

# %%
avogadro_number
# Out:
# 6.02214076e+23

# %%
type(avogadro_number)
# Out:
# float

# %%
int
(avogadro_number)
# Out:
# 6.02214076e+23

# %%
type(45*3.0)
# Out:
# float

# %%
type(45 * 3)
# Out:
# int

# %%
type(10/3)
# Out:
# float

# %%
type(10/2)
# Out:
# float

# %%
type(10//2)
# Out:
# int

# %%
is_today_Sunday = True

# %%
is_today_Sunday
# Out:
# True

# %%
type(is_today_Sunday)
# Out:
# bool

# %%
3 + True
# Out:
# 4

# %%
5 + False
# Out:
# 5

# %%
bool(False)
# Out:
# False

# %%
bool(0)
# Out:
# False

# %%
bool(0.0)
# Out:
# False

# %%
bool(None)
# Out:
# False

# %%
bool("")
# Out:
# False

# %%
bool([])
# Out:
# False

# %%
bool(set())
# Out:
# False

# %%
bool(range(0))
# Out:
# False

# %%
bool(True), bool(1), bool(2.0), bool("hello"), bool([1,2]), bool((2,3)), bool(range(10))
# Out:
# (True, True, True, True, True, True, True)

# %%
nothing = None

# %%
type(nothing)
# Out:
# NoneType

# %%
today = "Saturday"

# %%
today
# Out:
# 'Saturday'

# %%
type(today)
# Out:
# str

# %%
my_favorite_movie = "One Flew over the Cuckoo'a Nest"

# %%
my_favorite_movie
# Out:
# "One Flew over the Cuckoo'a Nest"

# %%
my_favorite_pun = 'Thanks for explaining the word "many" to me, it means a lot.'

# %%
my_favorite_pun
# Out:
# 'Thanks for explaining the word "many" to me, it means a lot.'

# %%
another_pun = "The first time I got a universal remote control, I thought to myself \"This changes everything\"."

# %%
another_pun
# Out:
# 'The first time I got a universal remote control, I thought to myself "This changes everything".'

# %%
yet_another_pun = '''Son: "Dad, can you tell me what a solar eclipse is?"
Dad: "No sun."'''

# %%
yet_another_pun
# Out:
# 'Son: "Dad, can you tell me what a solar eclipse is?" \nDad: "No sun."'

# %%
print(yet_another_pun)
# Out:
# Son: "Dad, can you tell me what a solar eclipse is?"
# Dad: "No sun."

# %%
a_music_pun = """
Two windmills are standing in a field and one asks the other,
"What kind of music do you like?"

The other says,
"I'm a big metal fan."
"""

# %%
print(a_music_pun)
# Out:
# Two windmills are standing in a field and one asks the other,
# "What kind of music do you like?"
#
# The other says,
# "I'm a big metal fan."

# %%
len(my_favorite_movie)
# Out:
# 31

# %%
multiline_string = """a
b"""
multiline_string
# Out:
# 'a\nb'

# %%
len(multiline_string)
# Out:
# 3

# %%
list(multiline_string)
# Out:
# ['a', '\n', 'b']

# %%
today = "Saturday"

# %%
today[0]
# Out:
# 'S'

# %%
today[3]
# Out:
# 'u'

# %%
today[7]
# Out:
# 'y'

# %%
today[5:8]
# Out:
# 'day'

# %%
'day' in today
# Out:
# True

# %%
"Sun" in today
# Out:
# False

# %%
full_name = "Derek O'Brien"

# %%
greeting = "Hello"

# %%
greeting + full_name
# Out:
# "HelloDerek O'Brien"

# %%
greeting + " " + full_name + "!" # additional space
# Out:
# "Hello Derek O'Brien!"

# %%
today.lower()
# Out:
# 'saturday'

# %%
"saturday".upper()
# Out:
# 'SATURDAY'

# %%
"monday".capitalize
# Out:
# <function str.capitalize()>

# %%
another_day = today.replace("Satur", "Wednes")

# %%
another_day
# Out:
# 'Wednesday'

# %%
today
# Out:
# 'Saturday'

# %%
"Sun,Mon,Tue,Wed,Thu,Fri,Sat".split(",")
# Out:
# ['Sun', 'Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat']

# %%
a_long_line = "       This is a long line with some space before, after,     and some space in the middle..    "

# %%
a_long_line_stripped = a_long_line.strip()

# %%
a_long_line_stripped
# Out:
# 'This is a long line with some space before, after,     and some space in the middle..'

# %%
# Input variables
cost_of_ice_bag = 1.25
profit_margin = .2
number_of_bags = 500

# Template for output message
output_template = """If a grocery store sells ice bags at $ {} per bag, with a profit margin of {} %,
then the total profit it makes by selling {} ice bags is $ {}."""

print(output_template)
# Out:
# If a grocery store sells ice bags at $ {} per bag, with a profit margin of {} %,
# then the total profit it makes by selling {} ice bags is $ {}.

# %%
# Inserting values into the string
total_profit = cost_of_ice_bag * profit_margin * number_of_bags
output_message = output_template.format(cost_of_ice_bag, profit_margin*100, number_of_bags, total_profit)

print(output_message)
# Out:
# If a grocery store sells ice bags at $ 1.25 per bag, with a profit margin of 20.0 %,
# then the total profit it makes by selling 500 ice bags is $ 125.0.

# %%
"If a grocery store sells ice bags at $ " + cost_of_ice_bag + ", with a profit margin of " + profit_margin
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_831/1331907882.py in <cell line: 0>()
# ----> 1 "If a grocery store sells ice bags at $ " + cost_of_ice_bag + ", with a profit margin of " + profit_margin
#
# TypeError: can only concatenate str (not "float") to str

# %%
"If a grocery store sells ice bags at $ " + str(cost_of_ice_bag) + ", with a profit margin of " + str(profit_margin)
# Out:
# 'If a grocery store sells ice bags at $ 1.25, with a profit margin of 0.2'

# %%
str(23)
# Out:
# '23'

# %%
str(23.456)
# Out:
# '23.456'

# %%
str(True)
# Out:
# 'True'

# %%
the_3_musketeers = ["Athos", "Porthos", "Aramis"]
str(the_3_musketeers)
# Out:
# "['Athos', 'Porthos', 'Aramis']"

# %%
first_name = "John"

# %%
first_name == "Doe"
# Out:
# False

# %%
first_name == "John"
# Out:
# True

# %%
first_name != "Jane"
# Out:
# True

# %%
fruits = ['apple', 'banana', 'cherry']

# %%
fruits
# Out:
# ['apple', 'banana', 'cherry']

# %%
type(fruits)
# Out:
# list

# %%
a_list = [23, 'hello', None, 3.14, fruits, 3 <= 5]

# %%
a_list
# Out:
# [23, 'hello', None, 3.14, ['apple', 'banana', 'cherry'], True]

# %%
empty_list = []

# %%
empty_list
# Out:
# []

# %%
len(fruits)
# Out:
# 3

# %%
print("Number of fruits:", len(fruits))
# Out:
# Number of fruits: 3

# %%
len(a_list)
# Out:
# 6

# %%
len(empty_list)
# Out:
# 0

# %%
fruits[0]
# Out:
# 'apple'

# %%
fruits[1]
# Out:
# 'banana'

# %%
fruits[2]
# Out:
# 'cherry'

# %%
fruits[3]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_831/1511222973.py in <cell line: 0>()
# ----> 1 fruits[3]
#
# IndexError: list index out of range

# %%
fruits[4]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_831/242072258.py in <cell line: 0>()
# ----> 1 fruits[4]
#
# IndexError: list index out of range

# %%
fruits[-1]
# Out:
# 'cherry'

# %%
fruits[-2]
# Out:
# 'banana'

# %%
fruits[-3]
# Out:
# 'apple'

# %%
fruits[-4]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_831/4281187226.py in <cell line: 0>()
# ----> 1 fruits[-4]
#
# IndexError: list index out of range

# %%
a_list = [23, 'hello', None, 3.14, fruits, 3 <= 5]

# %%
a_list
# Out:
# [23, 'hello', None, 3.14, ['apple', 'banana', 'cherry'], True]

# %%
a_list
# Out:
# [23, 'hello', None, 3.14, ['apple', 'banana', 'cherry'], True]

# %%
len(a_list)
# Out:
# 6

# %%
a_list[2:5]
# Out:
# [None, 3.14, ['apple', 'banana', 'cherry']]

# %%
a_list[2:10]
# Out:
# [None, 3.14, ['apple', 'banana', 'cherry'], True]

# %%
list_a[2:10]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_831/4176575454.py in <cell line: 0>()
# ----> 1 list_a[2:10]
#
# NameError: name 'list_a' is not defined

# %%
a_list[2:]
# Out:
# [None, 3.14, ['apple', 'banana', 'cherry'], True]

# %%
a_list[:5]
# Out:
# [23, 'hello', None, 3.14, ['apple', 'banana', 'cherry']]

# %%
a_list[-2:-5]
# Out:
# []

# %%
a_list[-5:-2]
# Out:
# ['hello', None, 3.14]

# %%
fruits
# Out:
# ['apple', 'banana', 'cherry']

# %%
fruits[1] = 'blueberry'

# %%
fruits
# Out:
# ['apple', 'blueberry', 'cherry']

# %%
fruits.append('dates')

# %%
fruits
# Out:
# ['apple', 'blueberry', 'cherry', 'dates']

# %%
fruits.remove('blueberry')

# %%
fruits
# Out:
# ['apple', 'cherry', 'dates']

# %%
fruits
# Out:
# ['apple', 'cherry', 'dates']

# %%
fruits.pop(1)
# Out:
# 'cherry'

# %%
fruits
# Out:
# ['apple', 'dates']

# %%
fruits.pop()
# Out:
# 'dates'

# %%
fruits
# Out:
# ['apple']

# %%
'pineapple' in fruits
# Out:
# False

# %%
'cherry' in fruits
# Out:
# False

# %%
fruits
# Out:
# ['apple']

# %%
more_fruits = fruits + ['pineapple', 'tomato', 'guava'] + ['dates', 'banana']

# %%
more_fruits
# Out:
# ['apple', 'pineapple', 'tomato', 'guava', 'dates', 'banana']

# %%
more_fruits_copy = more_fruits.copy()

# %%
more_fruits_copy
# Out:
# ['apple', 'pineapple', 'tomato', 'guava', 'dates', 'banana']

# %%
# Modify the copy
more_fruits_copy.remove('pineapple')
more_fruits_copy.pop()
more_fruits_copy
# Out:
# ['apple', 'tomato', 'guava', 'dates']

# %%
more_fruits
# Out:
# ['apple', 'pineapple', 'tomato', 'guava', 'dates', 'banana']

# %%
more_fruits_not_a_copy = more_fruits

# %%
more_fruits_not_a_copy.remove('pineapple')
more_fruits_not_a_copy.pop()
# Out:
# 'banana'

# %%
more_fruits_not_a_copy
# Out:
# ['apple', 'tomato', 'guava', 'dates']

# %%
more_fruits
# Out:
# ['apple', 'tomato', 'guava', 'dates']

# %%
fruits = ('apple', 'cherry', 'dates')

# %%
len(fruits)
# Out:
# 3

# %%
fruits[0]
# Out:
# 'apple'

# %%
fruits[-2]
# Out:
# 'cherry'

# %%
'dates' in fruits
# Out:
# True

# %%
fruits [0] = 'avocado'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_831/3541955871.py in <cell line: 0>()
# ----> 1 fruits [0] = 'avocado'
#
# TypeError: 'tuple' object does not support item assignment

# %%
fruits.append('blueberry')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_831/907065787.py in <cell line: 0>()
# ----> 1 fruits.append('blueberry')
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
fruits.remove('apple')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_831/3735496710.py in <cell line: 0>()
# ----> 1 fruits.remove('apple')
#
# AttributeError: 'tuple' object has no attribute 'remove'

# %%
the_3_musketeers = 'Athos', 'Porthos', 'Aramis'

# %%
the_3_musketeers
# Out:
# ('Athos', 'Porthos', 'Aramis')

# %%
single_element_tuple = 4,

# %%
single_element_tuple
# Out:
# (4,)

# %%
another_single_element_tuple = (4,)

# %%
another_single_element_tuple
# Out:
# (4,)

# %%
not_a_tuple = (4)

# %%
not_a_tuple
# Out:
# 4

# %%
point = (3, 4)

# %%
point_x, point_y = point

# %%
point_x
# Out:
# 3

# %%
point_y
# Out:
# 4

# %%
tuple(['one', 'two', 'three'])
# Out:
# ('one', 'two', 'three')

# %%
list(('Athos', 'Porthos', 'Aramis'))
# Out:
# ['Athos', 'Porthos', 'Aramis']

# %%
a_tuple = 23, "hello", False, None, 23, 37, "hello"

# %%
help(a_tuple.count)
# Out:
# Help on built-in function count:
#
# count(value, /) method of builtins.tuple instance
#     Return number of occurrences of value.

# %%
person1 = {
    'name': 'John Doe',
    'sex': 'Male',
    'age': 32,
    'married': True
}

# %%
person1
# Out:
# {'name': 'John Doe', 'sex': 'Male', 'age': 32, 'married': True}

# %%
person2 = dict(name='Jane Judy', sex='Female', age=28, married=False)

# %%
person2
# Out:
# {'name': 'Jane Judy', 'sex': 'Female', 'age': 28, 'married': False}

# %%
type(person1)
# Out:
# dict

# %%
person1['name']
# Out:
# 'John Doe'

# %%
person1['married']
# Out:
# True

# %%
person2['name']
# Out:
# 'Jane Judy'

# %%
person1['address']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_831/786906807.py in <cell line: 0>()
# ----> 1 person1['address']
#
# KeyError: 'address'

# %%
person2.get("name")
# Out:
# 'Jane Judy'

# %%
person2.get("address", "Unknown")
# Out:
# 'Unknown'

# %%
'name' in person1
# Out:
# True

# %%
'address' in person1
# Out:
# False

# %%
person2['married']
# Out:
# False

# %%
person2['married'] = True

# %%
person2['married']
# Out:
# True

# %%
person1
# Out:
# {'name': 'John Doe', 'sex': 'Male', 'age': 32, 'married': True}

# %%
person1['address'] = '1, Penny Lane'

# %%
person1
# Out:
# {'name': 'John Doe',
#  'sex': 'Male',
#  'age': 32,
#  'married': True,
#  'address': '1, Penny Lane'}

# %%
person1.pop('address')
# Out:
# '1, Penny Lane'

# %%
person1
# Out:
# {'name': 'John Doe', 'sex': 'Male', 'age': 32, 'married': True}

# %%
person1.keys()
# Out:
# dict_keys(['name', 'sex', 'age', 'married'])

# %%
person1.values()
# Out:
# dict_values(['John Doe', 'Male', 32, True])

# %%
person1.items()
# Out:
# dict_items([('name', 'John Doe'), ('sex', 'Male'), ('age', 32), ('married', True)])

# %%
person1.items()[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_831/2295007945.py in <cell line: 0>()
# ----> 1 person1.items()[1]
#
# TypeError: 'dict_items' object is not subscriptable
